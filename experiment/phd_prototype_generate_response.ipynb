# %%
import sys
sys.path.append('..')

from egh_vlm.generate_response import generate_raw_responses

# %%
res = generate_raw_responses(
    save_path='../data/phd/phd_sampled_qwen3_vl_2b.json',
    dataset_path='../data/phd/phd_sampled.json',
    img_folder_path='../data/phd/images',
    prompt_path ='../data/phd.generate_v0.txt',
    sample_size=100
)
